# %%
# Always check current input path
import os
os.listdir(r"C:\Users\joshu\Documents\GitHub\Document-Classification-Using-CNN")
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'best_weight.hdf5',
#  'dataset',
#  'docClassifier',
#  'env',
#  'LICENSE',
#  'logs',
#  'ModelApi.ipynb',
#  'README.md',
#  'WebCrawler.ipynb']

# %%
# Define the constants

IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128
IMAGE_CHANNELS = 3
INPUT_SHAPE = (IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)
EPOCHS = 35
POOL_SIZE = 2
LR = 0.001

# %%
# Part 1 - Preparing data
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=40,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.2,
    height_shift_range=0.2)


test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(r'C:\Users\joshu\Documents\GitHub\Document-Classification-Using-CNN\dataset\training_set',
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'binary',
                                                 shuffle=True,
                                                 seed=42)

testing_set = test_datagen.flow_from_directory(r'C:\Users\joshu\Documents\GitHub\Document-Classification-Using-CNN\dataset\testing_set',
                                            target_size = (128, 128),
                                            batch_size = 1,
                                            shuffle=False,
                                            class_mode = 'binary')
# Out:
# Found 244 images belonging to 2 classes.
# Found 61 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# print 15 sample training image
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in training_set:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
# # Part 2 - Building the CNN
# # Importing the Keras libraries and packages
import time

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard

# Use EarlyStopping and ReduceLROnPlateau
# when train, it keep testing set separetely and if the error is not improve for 5 times, training stop
earlystop = EarlyStopping(monitor='val_loss', patience=5, verbose=0)

# Save the best weight for epoch checkpoint
checkpointer = ModelCheckpoint(filepath = "best_weight.hdf5", monitor='val_loss', verbose=0, save_best_only=True)

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a CNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('ID') and 1 for the other ('Passport')
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %%
from tensorflow.keras.optimizers import Adam

print("Start training...")

STEP_SIZE_TRAIN = training_set.n//training_set.batch_size
STEP_SIZE_TEST = testing_set.n//testing_set.batch_size

# CONV_LAYERS = [1, 2, 3]
# LAYER_SIZES = [32, 64, 128]
# DENSE_LAYERS = [0, 1, 2]

CONV_LAYERS = [2]
LAYER_SIZES = [64]
DENSE_LAYERS = [2]

# Hyper-parameter tuning. Trial and Error
# Set Optimizer. Adam or RMSprop
# https://datascience.stackexchange.com/questions/43191/validation-loss-is-not-decreasing
opt = Adam(lr=LR, decay=1e-6)

for dense_layer in DENSE_LAYERS:
    for layer_size in LAYER_SIZES:
        for conv_layer in CONV_LAYERS:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)

            model = Sequential()
            
            # input layer 
            model.add(Conv2D(layer_size, (3, 3), input_shape = INPUT_SHAPE, activation = 'relu'))
            model.add(MaxPooling2D(pool_size = (POOL_SIZE, POOL_SIZE)))

            # hidden layer
            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
            
            # output layer
            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
            callbacks = [earlystop, checkpointer, tensorboard]

            model.compile(loss='binary_crossentropy',
                          optimizer=opt,
                          metrics=['binary_accuracy'])
            
            model.summary()
            
            history = model.fit_generator(training_set, 
                                epochs = EPOCHS, 
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data = testing_set,
                                validation_steps=STEP_SIZE_TEST,
                                callbacks=callbacks)
# Out:
# Start training...
# 2-conv-64-nodes-2-dense-1643004829
# c:\users\joshu\appdata\local\programs\python\python38\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 126, 64)      1792
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 61, 64)        36928
#
#  activation_8 (Activation)   (None, 61, 61, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 57600)             0
#
#  dense_6 (Dense)             (None, 64)                3686464
#
#  activation_9 (Activation)   (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  activation_10 (Activation)  (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
#  activation_11 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 3,729,409
# Trainable params: 3,729,409
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\joshu\AppData\Local\Temp/ipykernel_1312/3760911572.py:58: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(training_set,
# Epoch 1/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.9615 - binary_accuracy: 0.4906 - val_loss: 0.6738 - val_binary_accuracy: 0.5902
# Epoch 2/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.6491 - binary_accuracy: 0.6368 - val_loss: 0.7105 - val_binary_accuracy: 0.5082
# Epoch 3/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.6163 - binary_accuracy: 0.6226 - val_loss: 0.7884 - val_binary_accuracy: 0.5410
# Epoch 4/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.7326 - binary_accuracy: 0.5236 - val_loss: 0.6532 - val_binary_accuracy: 0.5082
# Epoch 5/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.6659 - binary_accuracy: 0.5943 - val_loss: 0.6970 - val_binary_accuracy: 0.5082
# Epoch 6/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.6774 - binary_accuracy: 0.5670 - val_loss: 0.6573 - val_binary_accuracy: 0.6721
# Epoch 7/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.6479 - binary_accuracy: 0.5982 - val_loss: 0.6543 - val_binary_accuracy: 0.5082
# Epoch 8/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.6069 - binary_accuracy: 0.6964 - val_loss: 0.5857 - val_binary_accuracy: 0.8033
# Epoch 9/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.5506 - binary_accuracy: 0.7453 - val_loss: 0.5028 - val_binary_accuracy: 0.7705
# Epoch 10/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.5147 - binary_accuracy: 0.7689 - val_loss: 0.4475 - val_binary_accuracy: 0.8197
# Epoch 11/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.5183 - binary_accuracy: 0.7311 - val_loss: 0.4817 - val_binary_accuracy: 0.7541
# Epoch 12/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.4604 - binary_accuracy: 0.7877 - val_loss: 0.4646 - val_binary_accuracy: 0.7541
# Epoch 13/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.4523 - binary_accuracy: 0.7830 - val_loss: 0.4416 - val_binary_accuracy: 0.7705
# Epoch 14/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.4609 - binary_accuracy: 0.7877 - val_loss: 0.4931 - val_binary_accuracy: 0.7705
# Epoch 15/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.4178 - binary_accuracy: 0.8208 - val_loss: 0.3896 - val_binary_accuracy: 0.8361
# Epoch 16/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.3689 - binary_accuracy: 0.8443 - val_loss: 0.3929 - val_binary_accuracy: 0.8525
# Epoch 17/35
# 7/7 [==============================] - 7s 978ms/step - loss: 0.3137 - binary_accuracy: 0.8774 - val_loss: 0.3565 - val_binary_accuracy: 0.8689
# Epoch 18/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.3430 - binary_accuracy: 0.8491 - val_loss: 0.4445 - val_binary_accuracy: 0.8361
# Epoch 19/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.3818 - binary_accuracy: 0.8349 - val_loss: 0.4278 - val_binary_accuracy: 0.8525
# Epoch 20/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.3332 - binary_accuracy: 0.8750 - val_loss: 0.3254 - val_binary_accuracy: 0.8689
# Epoch 21/35
# 7/7 [==============================] - 7s 1s/step - loss: 0.3112 - binary_accuracy: 0.8821 - val_loss: 0.3001 - val_binary_accuracy: 0.8852
# Epoch 22/35
# 7/7 [==============================] - 8s 1s/step - loss: 0.3134 - binary_accuracy: 0.8821 - val_loss: 0.3132 - val_binary_accuracy: 0.8852
# Epoch 23/35
# 7/7 [==============================] - 7s 972ms/step - loss: 0.3293 - binary_accuracy: 0.8632 - val_loss: 0.4319 - val_binary_accuracy: 0.8525
# Epoch 24/35
# 7/7 [==============================] - 7s 998ms/step - loss: 0.3155 - binary_accuracy: 0.8821 - val_loss: 0.3757 - val_binary_accuracy: 0.8852
# Epoch 25/35
# 7/7 [==============================] - 10s 1s/step - loss: 0.2519 - binary_accuracy: 0.9057 - val_loss: 0.3413 - val_binary_accuracy: 0.9016
# Epoch 26/35
# 7/7 [==============================] - 11s 1s/step - loss: 0.2739 - binary_accuracy: 0.9057 - val_loss: 0.3234 - val_binary_accuracy: 0.9180

# %%
# plot history
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Testing acc')
plt.title('Training and Testing accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Testing loss')
plt.title('Training and Testing loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
print(model.metrics_names)
model.evaluate(testing_set)
# Out:
# ['loss', 'binary_accuracy']
# 61/61 [==============================] - 2s 22ms/step - loss: 0.3234 - binary_accuracy: 0.9180
# [0.3234415650367737, 0.9180327653884888]

# %%
training_set.class_indices
# Out:
# {'identity_card': 0, 'passport': 1}

# %%
import seaborn as sns
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

labels = testing_set.class_indices

Y_pred = model.predict_generator(testing_set, testing_set.n // testing_set.batch_size)
y_pred = np.where(Y_pred>0.5, 1, 0)

print('Confusion Matrix')
cm = confusion_matrix(testing_set.classes, y_pred)
ax = plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, cmap='OrRd'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(labels); ax.yaxis.set_ticklabels(labels);
# Out:
# C:\Users\joshu\AppData\Local\Temp/ipykernel_1312/2455854477.py:7: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = model.predict_generator(testing_set, testing_set.n // testing_set.batch_size)
# Confusion Matrix

# %%
print('Classification Report')
print(classification_report(testing_set.classes, y_pred, target_names=labels))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
# identity_card       0.96      0.87      0.92        31
#      passport       0.88      0.97      0.92        30
#
#      accuracy                           0.92        61
#     macro avg       0.92      0.92      0.92        61
#  weighted avg       0.92      0.92      0.92        61

# %%
# Part 3 - Making new prediction on single set

from keras.preprocessing import image
import numpy as np

test_image = image.load_img(r'C:\Users\joshu\Downloads\Documents\Personal\Frontid.jpg', target_size = INPUT_SHAPE)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)

if result[0][0] == 1:
    prediction = 'ID'
else:
    prediction = 'Passport'

print(prediction)
# Out:
# ID

# %%
from keras.models import load_model

model.save(r'C:\Users\joshu\Documents\GitHub\Document-Classification-Using-CNN\model.h5')
